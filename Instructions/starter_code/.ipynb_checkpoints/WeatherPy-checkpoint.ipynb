# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
while (len(cities) < 500):
    cities = []
    # Create a set of random lat and lng combinations
    lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
    lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
    lat_lngs = zip(lats, lngs)

    # Identify nearest city for each lat, lng combination
    for lat_lng in lat_lngs:
        city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

        # If the city is unique, then add it to a our cities list
        if city not in cities:
            cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval\n-----------------------------")
sets = round(len(cities)/60+.5)
cityD = {"City":1,"Cloudiness":2,"Country":3,"Date":4,"Humidity":5,"Lat":6,"Lng":7,"Max Temp":8,"Wind Speed":9}
cityDList = []
units = "imperial"
for i in range(1,sets+1):
    start = (i-1)*60
    if (len(cities)-start) > 60:
        for j in range(start,(start+60)):
            try:
                received = requests.get(f"http://api.openweathermap.org/data/2.5/weather?q={cities[j]}&units={units}&appid={api_key}").json()
                cityD["City"] = cities[j]
                cityD["Cloudiness"] = received["clouds"]["all"]
                cityD["Country"] = received["sys"]["country"]
                cityD["Date"] = time.time()
                cityD["Humidity"] = received["main"]["humidity"]
                cityD["Lat"] = received["coord"]["lat"]
                cityD["Lng"] = received["coord"]["lon"]
                cityD["Max Temp"] = received["main"]["temp_max"]
                cityD["Wind Speed"] = received["wind"]["speed"]
                cityDList.append(cityD.copy())
                print(f"Processing Record {(j-start)} of Set {i} | {cities[j]}")
            except:
                print("City not found. Skipping...")
    else:
        for j in range(start,len(cities)):
            try:
                received = requests.get(f"http://api.openweathermap.org/data/2.5/weather?q={cities[j]}&units={units}&appid={api_key}").json()
                cityD["City"] = cities[j]
                cityD["Cloudiness"] = received["clouds"]["all"]
                cityD["Country"] = received["sys"]["country"]
                cityD["Date"] = time.time()
                cityD["Humidity"] = received["main"]["humidity"]
                cityD["Lat"] = received["coord"]["lat"]
                cityD["Lng"] = received["coord"]["lon"]
                cityD["Max Temp"] = received["main"]["temp_max"]
                cityD["Wind Speed"] = received["wind"]["speed"]
                cityDList.append(cityD.copy())
                print(f"Processing Record {(j-start)} of Set {i} | {cities[j]}")
            except:
                print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 1 | ilanskiy
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | mahebourg
# Processing Record 3 of Set 1 | thinadhoo
# Processing Record 4 of Set 1 | lasa
# Processing Record 5 of Set 1 | wynyard
# Processing Record 6 of Set 1 | kodiak
# City not found. Skipping...
# Processing Record 8 of Set 1 | henties bay
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | norman wells
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | ilulissat
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | salama
# Processing Record 15 of Set 1 | alice springs
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | xuddur
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | dikson
# Processing Record 20 of Set 1 | sorland
# Processing Record 21 of Set 1 | yerbogachen
# Processing Record 22 of Set 1 | esperance
# Processing Record 23 of Set 1 | bagua grande
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | barrow
# Processing Record 27 of Set 1 | vardo
# Processing Record 28 of Set 1 | pevek
# Processing Record 29 of Set 1 | iquique
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | brae
# Processing Record 33 of Set 1 | zhigansk
# Processing Record 34 of Set 1 | castro
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | airai
# Processing Record 37 of Set 1 | san patricio
# Processing Record 38 of Set 1 | codrington
# Processing Record 39 of Set 1 | vallenar
# Processing Record 40 of Set 1 | richards bay
# Processing Record 41 of Set 1 | mnogovershinnyy
# Processing Record 42 of Set 1 | plettenberg bay
# Processing Record 43 of Set 1 | dawlatabad
# Processing Record 44 of Set 1 | klaksvik
# Processing Record 45 of Set 1 | prainha
# Processing Record 46 of Set 1 | miri
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | inzer
# Processing Record 49 of Set 1 | verkhnyaya inta
# Processing Record 50 of Set 1 | port alfred
# City not found. Skipping...
# Processing Record 52 of Set 1 | rio gallegos
# City not found. Skipping...
# Processing Record 54 of Set 1 | eureka
# Processing Record 55 of Set 1 | salalah
# Processing Record 56 of Set 1 | kedougou
# Processing Record 57 of Set 1 | oum hadjer
# Processing Record 58 of Set 1 | konevo
# Processing Record 59 of Set 1 | dhidhdhoo
# Processing Record 0 of Set 2 | trairi
# Processing Record 1 of Set 2 | thompson
# Processing Record 2 of Set 2 | tiksi
# Processing Record 3 of Set 2 | la asuncion
# Processing Record 4 of Set 2 | temecula
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | narsaq
# Processing Record 7 of Set 2 | strangnas
# Processing Record 8 of Set 2 | nouadhibou
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | port elizabeth
# Processing Record 12 of Set 2 | chuy
# Processing Record 13 of Set 2 | mataura
# Processing Record 14 of Set 2 | verkh-suetka
# Processing Record 15 of Set 2 | kristianstad
# Processing Record 16 of Set 2 | lompoc
# Processing Record 17 of Set 2 | bandipur
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | panaba
# Processing Record 20 of Set 2 | grand gaube
# Processing Record 21 of Set 2 | bethel
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 2 | khatanga
# Processing Record 25 of Set 2 | iqaluit
# Processing Record 26 of Set 2 | puerto ayora
# City not found. Skipping...
# Processing Record 28 of Set 2 | isla vista
# Processing Record 29 of Set 2 | smithers
# City not found. Skipping...
# Processing Record 31 of Set 2 | kharp
# Processing Record 32 of Set 2 | kodinsk
# Processing Record 33 of Set 2 | yulara
# Processing Record 34 of Set 2 | mar del plata
# Processing Record 35 of Set 2 | comodoro rivadavia
# City not found. Skipping...
# Processing Record 37 of Set 2 | severo-kurilsk
# Processing Record 38 of Set 2 | tasiilaq
# Processing Record 39 of Set 2 | faanui
# Processing Record 40 of Set 2 | fuyu
# Processing Record 41 of Set 2 | upernavik
# Processing Record 42 of Set 2 | huarmey
# Processing Record 43 of Set 2 | mana
# City not found. Skipping...
# Processing Record 45 of Set 2 | avera
# Processing Record 46 of Set 2 | srednekolymsk
# Processing Record 47 of Set 2 | gilgit
# Processing Record 48 of Set 2 | taltal
# Processing Record 49 of Set 2 | brodnica
# City not found. Skipping...
# Processing Record 51 of Set 2 | kapaa
# Processing Record 52 of Set 2 | dwarka
# Processing Record 53 of Set 2 | hofn
# Processing Record 54 of Set 2 | pilar
# Processing Record 55 of Set 2 | saskylakh
# Processing Record 56 of Set 2 | rincon
# Processing Record 57 of Set 2 | abu kamal
# Processing Record 58 of Set 2 | jamestown
# Processing Record 59 of Set 2 | verkhovazhye
# Processing Record 0 of Set 3 | butaritari
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | shingu
# Processing Record 3 of Set 3 | ulaangom
# Processing Record 4 of Set 3 | camacha
# Processing Record 5 of Set 3 | tafalla
# Processing Record 6 of Set 3 | atuona
# Processing Record 7 of Set 3 | puerto escondido
# Processing Record 8 of Set 3 | curup
# Processing Record 9 of Set 3 | aktau
# Processing Record 10 of Set 3 | la ronge
# Processing Record 11 of Set 3 | ribeira grande
# Processing Record 12 of Set 3 | metro
# Processing Record 13 of Set 3 | khani
# City not found. Skipping...
# Processing Record 15 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 3 | zuenoula
# Processing Record 17 of Set 3 | avarua
# Processing Record 18 of Set 3 | fortuna
# Processing Record 19 of Set 3 | boende
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 22 of Set 3 | hasaki
# City not found. Skipping...
# Processing Record 24 of Set 3 | boguchany
# Processing Record 25 of Set 3 | listvyagi
# Processing Record 26 of Set 3 | sabha
# Processing Record 27 of Set 3 | kawalu
# Processing Record 28 of Set 3 | torbay
# Processing Record 29 of Set 3 | paengaroa
# Processing Record 30 of Set 3 | nemuro
# Processing Record 31 of Set 3 | general roca
# Processing Record 32 of Set 3 | mount gambier
# Processing Record 33 of Set 3 | saint george
# Processing Record 34 of Set 3 | lebu
# Processing Record 35 of Set 3 | provideniya
# Processing Record 36 of Set 3 | lihula
# Processing Record 37 of Set 3 | pisco
# City not found. Skipping...
# Processing Record 39 of Set 3 | dingle
# Processing Record 40 of Set 3 | aklavik
# Processing Record 41 of Set 3 | nuuk
# Processing Record 42 of Set 3 | port hueneme
# Processing Record 43 of Set 3 | necochea
# Processing Record 44 of Set 3 | jalu
# Processing Record 45 of Set 3 | bredasdorp
# Processing Record 46 of Set 3 | maldonado
# City not found. Skipping...
# Processing Record 48 of Set 3 | waddan
# Processing Record 49 of Set 3 | edgewater
# Processing Record 50 of Set 3 | yar-sale
# Processing Record 51 of Set 3 | dunedin
# Processing Record 52 of Set 3 | galesong
# Processing Record 53 of Set 3 | katsuura
# Processing Record 54 of Set 3 | pangnirtung
# Processing Record 55 of Set 3 | longyearbyen
# Processing Record 56 of Set 3 | wysokie mazowieckie
# Processing Record 57 of Set 3 | matara
# Processing Record 58 of Set 3 | husavik
# Processing Record 59 of Set 3 | chunoyar
# Processing Record 0 of Set 4 | brokopondo
# Processing Record 1 of Set 4 | enid
# Processing Record 2 of Set 4 | bam
# Processing Record 3 of Set 4 | chokurdakh
# Processing Record 4 of Set 4 | high level
# City not found. Skipping...
# Processing Record 6 of Set 4 | hornepayne
# Processing Record 7 of Set 4 | hobart
# Processing Record 8 of Set 4 | tuatapere
# Processing Record 9 of Set 4 | zhob
# Processing Record 10 of Set 4 | sao filipe
# Processing Record 11 of Set 4 | turukhansk
# Processing Record 12 of Set 4 | guerrero negro
# Processing Record 13 of Set 4 | ajdabiya
# Processing Record 14 of Set 4 | lavrentiya
# Processing Record 15 of Set 4 | tabora
# Processing Record 16 of Set 4 | noumea
# Processing Record 17 of Set 4 | santa lucia
# Processing Record 18 of Set 4 | ornskoldsvik
# Processing Record 19 of Set 4 | los llanos de aridane
# City not found. Skipping...
# Processing Record 21 of Set 4 | nabire
# Processing Record 22 of Set 4 | emba
# Processing Record 23 of Set 4 | abnub
# Processing Record 24 of Set 4 | amga
# Processing Record 25 of Set 4 | dudinka
# Processing Record 26 of Set 4 | menongue
# Processing Record 27 of Set 4 | mayumba
# Processing Record 28 of Set 4 | kavieng
# City not found. Skipping...
# Processing Record 30 of Set 4 | arak
# City not found. Skipping...
# Processing Record 32 of Set 4 | bonthe
# Processing Record 33 of Set 4 | davila
# Processing Record 34 of Set 4 | marsh harbour
# Processing Record 35 of Set 4 | massaguet
# Processing Record 36 of Set 4 | broken hill
# Processing Record 37 of Set 4 | thabazimbi
# City not found. Skipping...
# Processing Record 39 of Set 4 | griffith
# Processing Record 40 of Set 4 | bahia blanca
# Processing Record 41 of Set 4 | nikolskoye
# Processing Record 42 of Set 4 | saint-philippe
# Processing Record 43 of Set 4 | isangel
# City not found. Skipping...
# Processing Record 45 of Set 4 | christchurch
# Processing Record 46 of Set 4 | carutapera
# Processing Record 47 of Set 4 | moshny
# Processing Record 48 of Set 4 | tuktoyaktuk
# Processing Record 49 of Set 4 | kieta
# Processing Record 50 of Set 4 | sisimiut
# Processing Record 51 of Set 4 | taebla
# City not found. Skipping...
# Processing Record 53 of Set 4 | ayr
# Processing Record 54 of Set 4 | kihei
# Processing Record 55 of Set 4 | alpena
# Processing Record 56 of Set 4 | bathsheba
# Processing Record 57 of Set 4 | safford
# Processing Record 58 of Set 4 | el fuerte
# Processing Record 59 of Set 4 | aron
# Processing Record 0 of Set 5 | sahuaripa
# Processing Record 1 of Set 5 | fairbanks
# Processing Record 2 of Set 5 | petukhovo
# Processing Record 3 of Set 5 | abeche
# Processing Record 4 of Set 5 | zabaykalsk
# City not found. Skipping...
# Processing Record 6 of Set 5 | tual
# Processing Record 7 of Set 5 | jilin
# Processing Record 8 of Set 5 | luba
# Processing Record 9 of Set 5 | buzmeyin
# Processing Record 10 of Set 5 | labuhan
# Processing Record 11 of Set 5 | puerto penasco
# Processing Record 12 of Set 5 | kloulklubed
# Processing Record 13 of Set 5 | talnakh
# Processing Record 14 of Set 5 | umm kaddadah
# Processing Record 15 of Set 5 | bubaque
# City not found. Skipping...
# Processing Record 17 of Set 5 | muravlenko
# Processing Record 18 of Set 5 | kolvereid
# Processing Record 19 of Set 5 | inyonga
# Processing Record 20 of Set 5 | saint-joseph
# Processing Record 21 of Set 5 | nha trang
# Processing Record 22 of Set 5 | cidreira
# Processing Record 23 of Set 5 | coihaique
# Processing Record 24 of Set 5 | ahipara
# Processing Record 25 of Set 5 | mahibadhoo
# Processing Record 26 of Set 5 | denpasar
# Processing Record 27 of Set 5 | amapa
# Processing Record 28 of Set 5 | dakoro
# City not found. Skipping...
# Processing Record 30 of Set 5 | snyder
# Processing Record 31 of Set 5 | conde
# Processing Record 32 of Set 5 | saurimo
# Processing Record 33 of Set 5 | jian
# Processing Record 34 of Set 5 | quatre cocos
# Processing Record 35 of Set 5 | rawson
# Processing Record 36 of Set 5 | carnarvon
# Processing Record 37 of Set 5 | rio cuarto
# Processing Record 38 of Set 5 | santa cruz
# Processing Record 39 of Set 5 | ustrzyki dolne
# Processing Record 40 of Set 5 | sarkand
# Processing Record 41 of Set 5 | gisborne
# Processing Record 42 of Set 5 | port blair
# Processing Record 43 of Set 5 | clyde river
# Processing Record 44 of Set 5 | alcudia
# Processing Record 45 of Set 5 | shihezi
# Processing Record 46 of Set 5 | marsaxlokk
# Processing Record 47 of Set 5 | nome
# Processing Record 48 of Set 5 | penarroya-pueblonuevo
# Processing Record 49 of Set 5 | mont-de-marsan
# Processing Record 50 of Set 5 | whitehorse
# Processing Record 51 of Set 5 | ambilobe
# Processing Record 52 of Set 5 | goderich
# Processing Record 53 of Set 5 | kuusamo
# City not found. Skipping...
# Processing Record 55 of Set 5 | buala
# Processing Record 56 of Set 5 | shambu
# Processing Record 57 of Set 5 | kaitangata
# Processing Record 58 of Set 5 | kopaganj
# Processing Record 59 of Set 5 | almora
# Processing Record 0 of Set 6 | rodez
# Processing Record 1 of Set 6 | sistranda
# Processing Record 2 of Set 6 | mackenzie
# Processing Record 3 of Set 6 | ginir
# Processing Record 4 of Set 6 | victoria
# Processing Record 5 of Set 6 | bambanglipuro
# Processing Record 6 of Set 6 | huilong
# Processing Record 7 of Set 6 | nishihara
# Processing Record 8 of Set 6 | port hardy
# City not found. Skipping...
# Processing Record 10 of Set 6 | opuwo
# Processing Record 11 of Set 6 | san jose
# Processing Record 12 of Set 6 | akersberga
# Processing Record 13 of Set 6 | port-gentil
# Processing Record 14 of Set 6 | dubbo
# Processing Record 15 of Set 6 | olinda
# Processing Record 16 of Set 6 | moose jaw
# Processing Record 17 of Set 6 | amarante do maranhao
# Processing Record 18 of Set 6 | cherskiy
# Processing Record 19 of Set 6 | bajil
# Processing Record 20 of Set 6 | vila franca do campo
# City not found. Skipping...
# Processing Record 22 of Set 6 | tiznit
# Processing Record 23 of Set 6 | mecca
# Processing Record 24 of Set 6 | san luis
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 of Set 6 | inuvik
# Processing Record 28 of Set 6 | karratha
# Processing Record 29 of Set 6 | ippy
# Processing Record 30 of Set 6 | ocos
# Processing Record 31 of Set 6 | mangan
# Processing Record 32 of Set 6 | nhamunda
# Processing Record 33 of Set 6 | savannakhet
# Processing Record 34 of Set 6 | malibu
# Processing Record 35 of Set 6 | inhambane
# Processing Record 36 of Set 6 | cotonou
# Processing Record 37 of Set 6 | yatou
# Processing Record 38 of Set 6 | santa cruz de la palma
# Processing Record 39 of Set 6 | hirara
# Processing Record 40 of Set 6 | ariquemes
# Processing Record 41 of Set 6 | salair
# Processing Record 42 of Set 6 | gaoua
# Processing Record 43 of Set 6 | florianopolis
# City not found. Skipping...
# Processing Record 45 of Set 6 | lufilufi
# Processing Record 46 of Set 6 | del pilar
# Processing Record 47 of Set 6 | quarteira
# Processing Record 48 of Set 6 | hsinchu
# Processing Record 49 of Set 6 | carahue
# Processing Record 50 of Set 6 | pacific grove
# Processing Record 51 of Set 6 | kungurtug
# City not found. Skipping...
# Processing Record 53 of Set 6 | waipawa
# Processing Record 54 of Set 6 | marawi
# Processing Record 55 of Set 6 | tiarei
# Processing Record 56 of Set 6 | cadiz
# Processing Record 57 of Set 6 | tazovskiy
# Processing Record 58 of Set 6 | northam
# Processing Record 59 of Set 6 | ancud
# Processing Record 0 of Set 7 | solano
# Processing Record 1 of Set 7 | hami
# Processing Record 2 of Set 7 | nelson bay
# Processing Record 3 of Set 7 | moroto
# Processing Record 4 of Set 7 | namatanai
# Processing Record 5 of Set 7 | muhos
# Processing Record 6 of Set 7 | berndorf
# City not found. Skipping...
# Processing Record 8 of Set 7 | rundu
# Processing Record 9 of Set 7 | port augusta
# City not found. Skipping...
# Processing Record 11 of Set 7 | boyolangu
# Processing Record 12 of Set 7 | yendi
# Processing Record 13 of Set 7 | lichinga
# Processing Record 14 of Set 7 | egvekinot
# Processing Record 15 of Set 7 | talas
# Processing Record 16 of Set 7 | batemans bay
# Processing Record 17 of Set 7 | akureyri
# Processing Record 18 of Set 7 | ulaanbaatar
# Processing Record 19 of Set 7 | gwadar
# Processing Record 20 of Set 7 | road town
# Processing Record 21 of Set 7 | flinders
# City not found. Skipping...
# Processing Record 23 of Set 7 | sherlovaya gora
# Processing Record 24 of Set 7 | calvinia
# Processing Record 25 of Set 7 | bella union
# Processing Record 26 of Set 7 | kingaroy
# Processing Record 27 of Set 7 | acapulco
# Processing Record 28 of Set 7 | sambava
# Processing Record 29 of Set 7 | inongo
# Processing Record 30 of Set 7 | kachiry
# Processing Record 31 of Set 7 | meulaboh
# Processing Record 32 of Set 7 | marijampole
# Processing Record 33 of Set 7 | san pedro
# Processing Record 34 of Set 7 | capao da canoa
# City not found. Skipping...
# Processing Record 36 of Set 7 | souillac
# Processing Record 37 of Set 7 | havoysund
# Processing Record 38 of Set 7 | morondava
# Processing Record 39 of Set 7 | tilichiki
# Processing Record 40 of Set 7 | melbourne
# Processing Record 41 of Set 7 | sur
# Processing Record 42 of Set 7 | honiara
# Processing Record 43 of Set 7 | langsa
# Processing Record 44 of Set 7 | hanzhong
# Processing Record 45 of Set 7 | miquelon
# Processing Record 46 of Set 7 | north bend
# Processing Record 47 of Set 7 | san cristobal
# Processing Record 48 of Set 7 | tagusao
# Processing Record 49 of Set 7 | seoul
# Processing Record 50 of Set 7 | eldorado
# Processing Record 51 of Set 7 | masalli
# Processing Record 52 of Set 7 | two rivers
# Processing Record 53 of Set 7 | caravelas
# City not found. Skipping...
# Processing Record 55 of Set 7 | harper
# Processing Record 56 of Set 7 | danielskuil
# Processing Record 57 of Set 7 | beringovskiy
# Processing Record 58 of Set 7 | filadelfia
# Processing Record 59 of Set 7 | anadyr
# Processing Record 0 of Set 8 | takoradi
# Processing Record 1 of Set 8 | flekkefjord
# Processing Record 2 of Set 8 | zabid
# Processing Record 3 of Set 8 | carauari
# Processing Record 4 of Set 8 | edd
# Processing Record 5 of Set 8 | faya
# Processing Record 6 of Set 8 | kutum
# Processing Record 7 of Set 8 | aysha
# Processing Record 8 of Set 8 | komsomolskiy
# City not found. Skipping...
# Processing Record 10 of Set 8 | pinega
# Processing Record 11 of Set 8 | west bay
# Processing Record 12 of Set 8 | kasama
# Processing Record 13 of Set 8 | tourlaville
# Processing Record 14 of Set 8 | russell
# Processing Record 15 of Set 8 | taoudenni
# Processing Record 16 of Set 8 | porto novo
# Processing Record 17 of Set 8 | panji
# Processing Record 18 of Set 8 | oktyabrskoye
# Processing Record 19 of Set 8 | fukue
# Processing Record 20 of Set 8 | auki
# Processing Record 21 of Set 8 | lagoa
# Processing Record 22 of Set 8 | vilyuysk
# Processing Record 23 of Set 8 | san policarpo
# Processing Record 24 of Set 8 | nanortalik
# Processing Record 25 of Set 8 | chetumal
# Processing Record 26 of Set 8 | pringsewu
# City not found. Skipping...
# Processing Record 28 of Set 8 | buta
# Processing Record 29 of Set 8 | mehran
# Processing Record 30 of Set 8 | veinticinco de mayo
# Processing Record 31 of Set 8 | san juan del sur
# Processing Record 32 of Set 8 | chegdomyn
# Processing Record 33 of Set 8 | swan hill
# City not found. Skipping...
# Processing Record 35 of Set 8 | sydney
# Processing Record 36 of Set 8 | bulgan
# Processing Record 37 of Set 8 | port lincoln
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 40 of Set 8 | honghu
# Processing Record 41 of Set 8 | severo-zadonsk
# City not found. Skipping...
# Processing Record 43 of Set 8 | constitucion
# Processing Record 44 of Set 8 | arica
# Processing Record 45 of Set 8 | tyrma
# Processing Record 46 of Set 8 | kruisfontein
# Processing Record 47 of Set 8 | padang
# City not found. Skipping...
# Processing Record 49 of Set 8 | fraserburgh
# Processing Record 50 of Set 8 | limon
# Processing Record 51 of Set 8 | funadhoo
# Processing Record 52 of Set 8 | ereymentau
# Processing Record 53 of Set 8 | nabha
# Processing Record 54 of Set 8 | tahe
# Processing Record 55 of Set 8 | kem
# Processing Record 56 of Set 8 | ati
# Processing Record 57 of Set 8 | hualmay
# Processing Record 58 of Set 8 | jaguarari
# City not found. Skipping...
# Processing Record 0 of Set 9 | kattivakkam
# City not found. Skipping...
# Processing Record 2 of Set 9 | kalawit
# Processing Record 3 of Set 9 | timra
# Processing Record 4 of Set 9 | arlit
# Processing Record 5 of Set 9 | la baule-escoublac
# Processing Record 6 of Set 9 | khagaria
# Processing Record 7 of Set 9 | kamariotissa
# Processing Record 8 of Set 9 | paamiut
# Processing Record 9 of Set 9 | poronaysk
# Processing Record 10 of Set 9 | gunjur
# Processing Record 11 of Set 9 | hamilton
# Processing Record 12 of Set 9 | predivinsk
# Processing Record 13 of Set 9 | cacoal
# Processing Record 14 of Set 9 | dabat
# Processing Record 15 of Set 9 | campoverde
# Processing Record 16 of Set 9 | cabo san lucas
# Processing Record 17 of Set 9 | bambous virieux
# City not found. Skipping...
# Processing Record 19 of Set 9 | maputo
# Processing Record 20 of Set 9 | tura
# Processing Record 21 of Set 9 | ilebo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 9 | kilindoni
# Processing Record 25 of Set 9 | bassar
# Processing Record 26 of Set 9 | margate
# Processing Record 27 of Set 9 | ust-kuyga
# City not found. Skipping...
# Processing Record 29 of Set 9 | diamantino
# Processing Record 30 of Set 9 | churapcha
# Processing Record 31 of Set 9 | berezanka
# Processing Record 32 of Set 9 | leningradskiy
# Processing Record 33 of Set 9 | kiama
# Processing Record 34 of Set 9 | derzhavinsk
# Processing Record 35 of Set 9 | tygda
# Processing Record 36 of Set 9 | mantua
# Processing Record 37 of Set 9 | great yarmouth
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 40 of Set 9 | lorengau
# Processing Record 41 of Set 9 | kudahuvadhoo
# Processing Record 42 of Set 9 | joao pinheiro
# Processing Record 43 of Set 9 | borogontsy
# Processing Record 44 of Set 9 | palmer
# Processing Record 45 of Set 9 | kabala
# Processing Record 46 of Set 9 | bin qirdan
# Processing Record 47 of Set 9 | kalamata
# City not found. Skipping...
# Processing Record 49 of Set 9 | tautira
# Processing Record 50 of Set 9 | muros
# Processing Record 51 of Set 9 | riberalta
# Processing Record 52 of Set 9 | kodino
# City not found. Skipping...
# Processing Record 54 of Set 9 | clovis
# Processing Record 55 of Set 9 | yibin
# Processing Record 56 of Set 9 | genhe
# Processing Record 57 of Set 9 | seydi
# Processing Record 58 of Set 9 | iwaki
# Processing Record 59 of Set 9 | ponta do sol
# Processing Record 0 of Set 10 | iskateley
# Processing Record 1 of Set 10 | wattegama
# Processing Record 2 of Set 10 | mitsamiouli
# Processing Record 3 of Set 10 | merke
# Processing Record 4 of Set 10 | kholm
# Processing Record 5 of Set 10 | yenagoa
# Processing Record 6 of Set 10 | havelock
# Processing Record 7 of Set 10 | broome
# City not found. Skipping...
# Processing Record 9 of Set 10 | hobyo
# Processing Record 10 of Set 10 | prince rupert
# Processing Record 11 of Set 10 | simao
# City not found. Skipping...
# Processing Record 13 of Set 10 | kokopo
# Processing Record 14 of Set 10 | mubi
# Processing Record 15 of Set 10 | ostrovnoy
# Processing Record 16 of Set 10 | moree
# Processing Record 17 of Set 10 | thunder bay
# Processing Record 18 of Set 10 | burnie
# Processing Record 19 of Set 10 | erzin
# Processing Record 20 of Set 10 | leon
# Processing Record 21 of Set 10 | cayenne
# Processing Record 22 of Set 10 | alekseyevka
# Processing Record 23 of Set 10 | tieling
# Processing Record 24 of Set 10 | sangar
# Processing Record 25 of Set 10 | garowe
# Processing Record 26 of Set 10 | lerwick
# Processing Record 27 of Set 10 | hambantota
# Processing Record 28 of Set 10 | wyndham
# Processing Record 29 of Set 10 | ranong
# Processing Record 30 of Set 10 | ozark
# Processing Record 31 of Set 10 | fez
# Processing Record 32 of Set 10 | peleduy
# City not found. Skipping...
# Processing Record 34 of Set 10 | willmar
# Processing Record 35 of Set 10 | seymchan
# Processing Record 36 of Set 10 | san lazaro
# Processing Record 37 of Set 10 | port macquarie
# Processing Record 38 of Set 10 | sinop
# City not found. Skipping...
# Processing Record 40 of Set 10 | nagorsk
# Processing Record 41 of Set 10 | panama city
# Processing Record 42 of Set 10 | daoukro
# Processing Record 43 of Set 10 | raudeberg
# Processing Record 44 of Set 10 | yaan
# Processing Record 45 of Set 10 | fort nelson
# Processing Record 46 of Set 10 | hokitika
# Processing Record 47 of Set 10 | port said
# Processing Record 48 of Set 10 | sao joao da barra
# Processing Record 49 of Set 10 | poum
# Processing Record 50 of Set 10 | yangshe
# Processing Record 51 of Set 10 | santa catarina de tepehuanes
# Processing Record 52 of Set 10 | hukuntsi
# Processing Record 53 of Set 10 | spring hill
# Processing Record 54 of Set 10 | okhotsk
# Processing Record 55 of Set 10 | varna
# Processing Record 56 of Set 10 | robe
# Processing Record 57 of Set 10 | mount isa
# Processing Record 58 of Set 10 | kushiro
# Processing Record 59 of Set 10 | alexandria
# Processing Record 0 of Set 11 | makakilo city
# Processing Record 1 of Set 11 | aguimes
# Processing Record 2 of Set 11 | znamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 11 | granard
# Processing Record 5 of Set 11 | waingapu
# Processing Record 6 of Set 11 | zapolyarnyy
# City not found. Skipping...
# Processing Record 8 of Set 11 | sitka
# Processing Record 9 of Set 11 | tecpan guatemala
# Processing Record 10 of Set 11 | xichang
# Processing Record 11 of Set 11 | gat
# Processing Record 12 of Set 11 | yeppoon
# Processing Record 13 of Set 11 | biak
# Processing Record 14 of Set 11 | fort saint james

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cityFrame = pd.DataFrame(cityDList)
cityFrame.to_csv("city_data.csv", encoding = "utf-8",index=False)
cityFrame
# Out:
#                              City  Cloudiness Country          Date  Humidity  \
# 0                        ilanskiy          76      RU  1.552943e+09        86
# 1                        hermanus           0      ZA  1.552943e+09        90
# 2                       mahebourg          20      MU  1.552943e+09        83
# 3                       thinadhoo           0      MV  1.552943e+09       100
# 4                            lasa          20      CY  1.552943e+09        87
# 5                         wynyard          24      CA  1.552943e+09        97
# 6                          kodiak           1      US  1.552943e+09         6
# 7                     henties bay           0      NA  1.552943e+09        92
# 8                           bluff           0      AU  1.552943e+09        93
# 9                    norman wells          75      CA  1.552943e+09        49
# 10                    yellowknife          75      CA  1.552943e+09        91
# 11                      ilulissat          40      GL  1.552943e+09        44
# 12                     georgetown          40      GY  1.552943e+09        66
# 13                         salama          40      GT  1.552943e+09        38
# 14                  alice springs          32      AU  1.552943e+09        22
# 15                        rikitea          76      PF  1.552943e+09       100
# 16                         xuddur           0      SO  1.552943e+09        41
# 17                      hithadhoo          76      MV  1.552943e+09       100
# 18                         dikson          80      RU  1.552943e+09        93
# 19                        sorland          20      NO  1.552943e+09        74
# 20                    yerbogachen          64      RU  1.552943e+09        80
# 21                      esperance          20      TT  1.552943e+09        51
# 22                   bagua grande          44      PE  1.552943e+09        82
# 23                      cape town           0      ZA  1.552943e+09        91
# 24                    new norfolk          40      AU  1.552943e+09        87
# 25                         barrow           0      AR  1.552943e+09        71
# 26                          vardo          90      US  1.552943e+09        33
# 27                          pevek          56      RU  1.552943e+09        84
# 28                        iquique           0      CL  1.552943e+09        53
# 29                        ushuaia          75      AR  1.552943e+09        94
# ..                            ...         ...     ...           ...       ...
# 524                     raudeberg          20      NO  1.552943e+09        69
# 525                          yaan           8      NG  1.552943e+09        52
# 526                   fort nelson          75      CA  1.552943e+09        35
# 527                      hokitika          44      NZ  1.552943e+09        98
# 528                     port said          44      EG  1.552943e+09        46
# 529             sao joao da barra          20      BR  1.552943e+09        58
# 530                          poum           0      MK  1.552943e+09        65
# 531                       yangshe           0      CN  1.552943e+09        95
# 532  santa catarina de tepehuanes          24      MX  1.552943e+09        25
# 533                      hukuntsi           0      BW  1.552943e+09        46
# 534                   spring hill           1      US  1.552943e+09        37
# 535                       okhotsk           0      RU  1.552943e+09       100
# 536                         varna           0      BG  1.552943e+09        87
# 537                          robe           0      ET  1.552943e+09        71
# 538                     mount isa           0      AU  1.552943e+09        52
# 539                       kushiro          80      JP  1.552943e+09        78
# 540                    alexandria           1      US  1.552943e+09        30
# 541                 makakilo city          20      US  1.552943e+09        47
# 542                       aguimes          20      ES  1.552943e+09        63
# 543                   znamenskoye          80      RU  1.552943e+09        76
# 544                       granard          92      IE  1.552943e+09        96
# 545                      waingapu          32      ID  1.552943e+09        97
# 546                   zapolyarnyy          75      RU  1.552943e+09        92
# 547                         sitka           0      US  1.552943e+09        40
# 548              tecpan guatemala          40      GT  1.552943e+09        38
# 549                       xichang          12      CN  1.552943e+09        29
# 550                           gat           0      SN  1.552943e+09        36
# 551                       yeppoon           0      AU  1.552943e+09        94
# 552                          biak           0      ID  1.552943e+09        96
# 553              fort saint james          12      CA  1.552943e+09        60
#
#        Lat     Lng  Max Temp  Wind Speed
# 0    56.24   96.06     22.11        8.37
# 1   -34.42   19.24     68.00        1.99
# 2   -20.41   57.70     80.60        3.36
# 3     0.53   72.93     83.76        3.60
# 4    34.92   32.53     60.80        3.36
# 5    51.77 -104.18     33.81       10.04
# 6    39.95  -94.76     54.00        5.82
# 7   -22.12   14.28     62.01        1.99
# 8   -23.58  149.07     67.29        3.49
# 9    65.28 -126.83     46.40        4.70
# 10   62.45 -114.38     39.99        9.17
# 11   69.22  -51.10     -2.21        4.70
# 12    6.80  -58.16     86.00       11.41
# 13   15.11  -90.32     77.00       16.11
# 14  -23.70  133.88     66.20        6.93
# 15  -23.12 -134.97     77.55       19.55
# 16    4.12   43.89     78.09        9.42
# 17   -0.60   73.08     84.21        6.40
# 18   73.51   80.55     22.74       21.45
# 19   67.67   12.69     28.40        3.36
# 20   61.28  108.01     11.49        2.82
# 21   10.24  -61.45     87.01       17.22
# 22   -5.75  -78.44     70.53        2.26
# 23  -33.93   18.42     73.00        4.00
# 24  -42.78  147.06     54.00        4.70
# 25  -38.31  -60.23     64.14       12.28
# 26   39.62  -77.74     48.99        5.82
# 27   69.70  170.27     -5.98       29.17
# 28  -20.22  -70.14     73.40       13.87
# 29  -54.81  -68.31     42.80       18.34
# ..     ...     ...       ...         ...
# 524  61.99    5.14     39.20        5.82
# 525   7.38    8.57     86.10        9.15
# 526  58.81 -122.69     57.20        5.82
# 527 -42.72  170.96     63.51        0.87
# 528  25.34   30.55     57.48        7.63
# 529 -21.64  -41.05     86.00       16.11
# 530  41.28   20.71     44.60        3.36
# 531  31.89  120.61     54.00        3.22
# 532  25.34 -105.72     66.66        7.25
# 533 -23.98   21.76     71.70        5.39
# 534  28.46  -82.54     73.40        6.93
# 535  59.36  143.24     -3.37        6.80
# 536  43.22   27.90     48.20        6.93
# 537   7.12   40.01     48.75        4.00
# 538 -20.73  139.49     68.00        4.38
# 539  43.11  144.15     35.61        9.53
# 540  31.31  -92.44     70.00        6.93
# 541  21.35 -158.09     80.01       11.05
# 542  27.91  -15.45     64.99       21.92
# 543  57.13   73.82     11.76        5.06
# 544  53.78   -7.49     45.96        7.07
# 545  -9.65  120.26     73.77        5.35
# 546  69.43   30.82     30.20       32.21
# 547  37.17  -99.65     60.01        4.00
# 548  14.77  -90.99     79.00       16.11
# 549  27.88  102.25     54.51        3.27
# 550  14.69  -16.54     78.80       16.11
# 551 -23.13  150.74     71.60        3.78
# 552  -0.91  122.88     76.38        2.37
# 553  54.43 -124.25     45.96        2.89
#
# [554 rows x 9 columns]

# %%
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     lompoc           1      US  1534984500        44  34.64 -120.46
# 1   klaksvik          92      FO  1534983600       100  62.23   -6.59
# 2  bisignano           0      IT  1534981800        88  39.50   16.27
# 3       hilo          90      US  1534984860        90  19.71 -155.08
# 4    rikitea           8      PF  1534986579       100 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     77.00       11.41
# 1     50.00       13.87
# 2     66.20        5.82
# 3     77.00        8.05
# 4     69.58       19.71

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
cityFrame.plot(kind ="scatter",x="Lat",y="Max Temp",marker="o", edgecolor="black",grid=True,s=35,alpha=.8)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
date = time.strftime('%m/%d/%Y')
plt.title(f"City Latitude vs. Max Temperature ({date})")
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Max Temperature (03/18/2019)')

# %%
cityFrame.plot(kind ="scatter",x="Lat",y="Humidity",marker="o", edgecolor="black",grid=True,s=35,alpha=.8)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
date = time.strftime('%m/%d/%Y')
plt.title(f"City Latitude vs. Humidity ({date})")
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Humidity (03/18/2019)')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
cityFrame.plot(kind ="scatter",x="Lat",y="Cloudiness",marker="o", edgecolor="black",grid=True,s=35,alpha=.8)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
date = time.strftime('%m/%d/%Y')
plt.title(f"City Latitude vs. Cloudiness ({date})")
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Cloudiness (03/18/2019)')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
cityFrame.plot(kind ="scatter",x="Lat",y="Wind Speed",marker="o", edgecolor="black",grid=True,s=35,alpha=.8)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
date = time.strftime('%m/%d/%Y')
plt.title(f"City Latitude vs. Wind Speed ({date})")
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Wind Speed (03/18/2019)')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
